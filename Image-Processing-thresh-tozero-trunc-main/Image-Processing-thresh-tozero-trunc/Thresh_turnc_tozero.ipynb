# %%
import matplotlib.pyplot as plt
import cv2

# %%
my_img = cv2.imread("cameraman.jpg")

# %%
my_img2 = cv2.cvtColor(my_img,cv2.COLOR_BGR2GRAY)

# %%
my_img2
# Out:
# array([[171, 171, 173, ..., 167, 167, 167],
#        [173, 171, 173, ..., 167, 169, 167],
#        [173, 173, 173, ..., 167, 167, 167],
#        ...,
#        [141, 141, 141, ..., 141, 131, 131],
#        [139, 139, 139, ..., 143, 133, 133],
#        [143, 143, 141, ..., 137, 131, 131]], dtype=uint8)

# %%
cv2.imshow("image",my_img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(my_img.shape)
print(my_img2.shape)
# Out:
# (648, 648, 3)
# (648, 648)

# %% [markdown]
# ### esitleme

# %%
_, my_binary_thresh_img = cv2.threshold(my_img2,thresh = 125 , maxval =255 , type = cv2.THRESH_BINARY)

# %%
print(_)
# Out:
# 125.0

# %%
plt.imshow(my_binary_thresh_img,cmap= "gray")
plt.axis("off")
# Out:
# (-0.5, 647.5, 647.5, -0.5)

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows,columns,1)
plt.imshow(my_img2,cmap = "gray")
plt.axis("off")

fig.add_subplot(rows,columns,2)
plt.imshow(my_binary_thresh_img,cmap = "gray")
plt.axis("off")
# Out:
# (-0.5, 647.5, 647.5, -0.5)

# %%
_, my_binary_thresh_inv_img = cv2.threshold(my_img2,thresh = 125 , maxval =255 , type = cv2.THRESH_BINARY_INV)

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 2

fig.add_subplot(rows,columns,1)
plt.imshow(my_img2,cmap = "gray")
plt.axis("off")

fig.add_subplot(rows,columns,2)
plt.imshow(my_binary_thresh_inv_img,cmap = "gray")
plt.axis("off")
# Out:
# (-0.5, 647.5, 647.5, -0.5)

# %%
fig = plt.figure(figsize=(10, 7))
rows = 1
columns = 3


fig.add_subplot(rows,columns,1)
plt.imshow(my_img2,cmap = "gray")
plt.axis("off")



fig.add_subplot(rows,columns,2)
plt.imshow(my_binary_thresh_inv_img,cmap = "gray")
plt.axis("off")



fig.add_subplot(rows,columns,3)
plt.imshow(my_binary_thresh_img,cmap= "gray")
plt.axis("off")
# Out:
# (-0.5, 647.5, 647.5, -0.5)

# %%
_, my_binary_thresh_TRUNC_img = cv2.threshold(my_img2,thresh = 125 , maxval =255 , type = cv2.THRESH_TRUNC)

# %%
fig = plt.figure(figsize=(10, 7))
rows = 2
columns = 2

fig.add_subplot(rows,columns,1)
plt.title("main")
plt.imshow(my_img2,cmap = "gray")
plt.axis("off")



fig.add_subplot(rows,columns,2)
plt.title("THRESH_INV")
plt.imshow(my_binary_thresh_inv_img,cmap = "gray")
plt.axis("off")



fig.add_subplot(rows,columns,3)
plt.title("THRESH")
plt.imshow(my_binary_thresh_img,cmap= "gray")
plt.axis("off")


fig.add_subplot(rows,columns,4)
plt.title("TRUNC")
plt.imshow(my_binary_thresh_TRUNC_img,cmap= "gray")
plt.axis("off")
# Out:
# (-0.5, 647.5, 647.5, -0.5)

# %%
_, my_binary_thresh_Tozero_img = cv2.threshold(my_img2,thresh = 125 , maxval =255 , type = cv2.THRESH_TOZERO)
_, my_binary_thresh_Tozero_inv_img = cv2.threshold(my_img2,thresh = 125 , maxval =255 , type = cv2.THRESH_TOZERO_INV)

# %%
fig = plt.figure(figsize=(10, 7))
rows = 3
columns = 2

fig.add_subplot(rows,columns,1)
plt.title("main")
plt.imshow(my_img2,cmap = "gray")
plt.axis("off")



fig.add_subplot(rows,columns,2)
plt.title("TURNC")
plt.imshow(my_binary_thresh_TRUNC_img,cmap = "gray")
plt.axis("off")



fig.add_subplot(rows,columns,3)
plt.title("THRESH")
plt.imshow(my_binary_thresh_img,cmap= "gray")
plt.axis("off")


fig.add_subplot(rows,columns,4)
plt.title("THRESH INV")
plt.imshow(my_binary_thresh_inv_img,cmap= "gray")
plt.axis("off")

fig.add_subplot(rows,columns,5)
plt.title("tozero")
plt.imshow(my_binary_thresh_Tozero_img,cmap= "gray")
plt.axis("off")


fig.add_subplot(rows,columns,6)
plt.title("tozero inv")
plt.imshow(my_binary_thresh_Tozero_inv_img,cmap= "gray")
plt.axis("off")
# Out:
# (-0.5, 647.5, 647.5, -0.5)

# %%
cv2.imwrite("./nebula.jpg",my_img)
# Out:
# True

# %%
    cv2.imwrite("./turnc.jpg",my_binary_thresh_TRUNC_img)
    cv2.imwrite("./thresh.jpg",my_binary_thresh_img)
    cv2.imwrite("./threshinv.jpg",my_binary_thresh_inv_img)
    cv2.imwrite("./tozero.jpg",my_binary_thresh_Tozero_img)
    cv2.imwrite("./tozeroinv.jpg",my_binary_thresh_Tozero_inv_img)
# Out:
# True
